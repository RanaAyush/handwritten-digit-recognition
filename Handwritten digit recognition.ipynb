# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
from keras.datasets import mnist
from tensorflow.math import confusion_matrix
# Out:
# WARNING:tensorflow:From C:\Users\Ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
print(x_train.shape,y_train.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
x_train = x_train/255
x_test = x_test/255

# %%
model =  keras.Sequential([ keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(50,activation='relu'),
                          keras.layers.Dense(50,activation='relu'),
                          keras.layers.Dense(10,activation='sigmoid'),
])
# Out:
# WARNING:tensorflow:From C:\Users\Ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 3s 990us/step - loss: 0.2996 - accuracy: 0.9128
# Epoch 2/10
# 1875/1875 [==============================] - 2s 948us/step - loss: 0.1391 - accuracy: 0.9582
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1021 - accuracy: 0.9688
# Epoch 4/10
# 1875/1875 [==============================] - 2s 962us/step - loss: 0.0819 - accuracy: 0.9751
# Epoch 5/10
# ...

# %%
loss, accuracy = model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 789us/step - loss: 0.0915 - accuracy: 0.9764

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 799us/step

# %%
print(y_pred[0])
# Out:
# [2.9750721e-05 1.0027487e-02 8.9961934e-01 9.8261476e-01 4.3596164e-03
#  1.8530841e-04 8.9518554e-10 9.9999952e-01 4.9924664e-02 4.3380901e-01]

# %%
first_pred = np.argmax(y_pred[0])
print(first_pred)
# Out:
# 7

# %%
y_all_labels = [np.argmax(i) for i in y_pred]
print(y_all_labels)
# Out:
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4, 9, 6, 6, 5, 4, 0, 7, 4, 0, 1, 3, 1, 3, 4, 7, 2, 7, 1, 2, 1, 1, 7, 4, 2, 3, 5, 1, 2, 4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 8, 9, 3, 7, 4, 6, 4, 3, 0, 7, 0, 2, 9, 1, 7, 3, 2, 9, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 9, 3, 1, 4, 1, 7, 6, 9, 6, 0, 5, 4, 5, 9, 2, 1, 9, 4, 8, 7, 3, 9, 7, 9, 4, 4, 9, 2, 5, 4, 7, 6, 7, 9, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 3, 1, 7, 1, 8, 2, 0, 9, 9, 9, 5, 5, 1, 5, 6, 0, 3, 4, 4, 6, 5, 4, 6, 5, 4, 5, 1, 4, 4, 7, 2, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 8, 9, 2, 5, 0, 1, 1, 1, 0, 9, 0, 3, 1, 6, 4, 2, 3, 6, 1, 1, 1, 3, 9, 5, 2, 9, 4, 5, 9, 3, 9, 0, 3, 6, 5, 5, 7, 2, 2, 7, 1, 2, 8, 4, 1, 7, 3, 3, 8, 8, 7, 9, 2, 2, 4, 1, 5, 9, 8, 7, 2, 3, 0, 2, 4, 2, 4, 1, 9, 5, 7, 7, 2, 8, 2, 6, 8, 5, 7, 7, 9, 1, 8, 1, 8, 0, 3, 0, 1, 9, 9, 4, 1, 8, 2, 1, 2, 9, 7, 5, 9, 2, 6, 4, 1, 5, 8, 2, 9, 2, 0, 4, 0, 0, 2, 8, 4, 7, 1, 2, 4, 0, 2, 7, 4, 3, 3, 0, 0, 3, 1, 9, 6, 5, 2, 5, 9, 7, 9, 3, 0, 4, 2, 0, 7, 1, 1, 2, 1
# ...

# %%
input_image = cv2.imread('digit.png')

# %%
grayscale = cv2.cvtColor(input_image,cv2.COLOR_RGB2GRAY)

# %%
grayscale = cv2.resize(grayscale,(28,28))
graysacle = grayscale/255
img_reshaped = np.reshape(graysacle,[1,28,28])

# %%
input_pred = model.predict(img_reshaped)
print(input_pred)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[2.0786173e-11 2.3752395e-06 1.5149748e-06 1.0000000e+00 5.2013061e-09
#   9.9543786e-01 2.1454850e-17 4.0711011e-04 4.8935586e-03 9.9769229e-01]]

# %%
print(np.argmax(input_pred))
# Out:
# 3
